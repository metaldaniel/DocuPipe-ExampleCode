# %%
import os
import base64
import requests
from time import sleep
from dotenv import load_dotenv


# Load variables from .env file
load_dotenv()
API_KEY = os.environ.get("MY_API_KEY")


def process_document(file_name):
    url = "https://app.docupipe.ai/document"
    
    payload = {"document": {"file": {
        "contents": base64.b64encode(open(file_name, 'rb').read()).decode(),
        "filename": file_name
    }}}
    headers = {
        "accept": "application/json",
        "content-type": "application/json",
        "X-API-Key": API_KEY
    }
    
    response = requests.post(url, json=payload, headers=headers)
    return response.json()['documentId']


def check_result(document_id):
    url = f"https://app.docupipe.ai/document/{document_id}"

    headers = {
        "accept": "application/json",
        "X-API-Key": API_KEY
    }

    response = requests.get(url, headers=headers)
    return response.json()


def extract_text_from_json(json_response):
    # Navigate to the result object which contains the actual document content
    if 'result' in json_response:
        json_data = json_response['result']
    else:
        json_data = json_response
    
    # Otherwise, we need to extract and combine text from each page
    combined_text = []
    
    if 'pages' in json_data:
        for i, page in enumerate(json_data['pages']):
            # If the page has a complete text field, use it
            if 'text' in page and page['text']:
                # Add page number header for multi-page documents
                if json_data.get('numPages', 1) > 1:
                    combined_text.append(f"Page {i+1}:\n===\n")
                combined_text.append(page['text'])
            # Otherwise combine text from sections
            elif 'sections' in page:
                page_text = []
                for section in page['sections']:
                    if 'text' in section and section['text']:
                        page_text.append(section['text'])
                
                if page_text:
                    # Add page number header for multi-page documents
                    if json_data.get('numPages', 1) > 1:
                        combined_text.append(f"Page {i+1}:\n===\n")
                    combined_text.append("\n\n".join(page_text))
    
    return "\n\n".join(combined_text) if combined_text else "No text found in the JSON response."


def do_ocr(file_name):
    document_id = process_document(file_name)
    print (document_id)
    sleep(5)
    result = check_result(document_id)
    
    while (result['status'] == 'processing'):
        print ("Processing...")
        sleep (5)
        result = check_result(document_id)
    
    full_text = extract_text_from_json(result)
    print(full_text)

# %%
do_ocr("Archives_OCR.pdf")
# Out:
# 7a1af467
# Page 1:
# ===
#
#
# 30 39
#
# JaD' wild west faly
#
# 13WENT Taip Te 9900 1/3/2,N /N /3 PoJN-N.3N 2 15 + 1969
#
# 5/25/6/12 /NO/3 Pp To pera pd >(?)
#
# שם תיק: ארכיון אליעזר רפאל מלאכי -קובץ לזכר גליה ירדני
#
# מזהה פיזי:
#
# פ-2446/30 001nder
#
# מזהה פריט:
#
# כתובת
#
# 2-109-1-13-3
#
# תאריד הדפסה 06/05/2021
#
# Page 3:
# ===
#
#
# ההסתדרות הכללית של העובדים בארץ ישראל
#
# הוצאת ספרים של הקיבוץ המאוחד בע״מ
#
# רח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 1,6040 תל־אביב
#
# יום.
#
# 7 במאי 1969
#
# לא״ר מלאכי שלום רב,
#
# כמי שהוטל עליו להתקין קובץ לזכרה של גליה ירדני הנני פונה אליך בזה בבקשה להמציא לנו את תרומתך לקובץ הזה, שיכיל שלושה מדורים: א) דברים על גליה ועל עבודתה המדעית; ב) חיבורים, מקשש הקשורים במישרין עם נושא מחקרה על הישוב בא״י בכלל ועל ירושלים בפרט; ב) מאמרים שלה, בעניינים שונים, שראו אור בזמנם.
#
# מדבריו של שמואל אגמון למדתי כי מוכנות אצלך הן רשימה על אישיותה של גליה והן עבודה מדעית מקיפה, הראויות לבוא שתיהן בקובץ הזה. אודה לך איפוא אם תואיל לשלוח לי את כתביהיד בהקדם.
#
# Image With Text:
# בברכה,
# אנPA גר מן
#
# Image
#
# Page 5:
# ===
#
#
# Image With Text:
# דואר אויר PAR AVION
#
# A.R. Malachi 2070 Grand Concourse Bronx N.Y. 10457
#
# U.S.A
#
# Now
#
# Image With Text:
# F
# -7.5.59
# TEL
# AFO
# 0.80
#
# Page 6:
# ===
#
#
# הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב
#
# Page 7:
# ===
#
#
# ההסתדרות הכללית של העובדים בארץ ישראל
#
# הוצאת ספרים של הקיבוץ המאוחד בע״מ
#
# רח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 16040 תל־אביב
#
# 15 ביוני 1969
#
# לא״ר מלאכי שלום וברכה,
#
# קודם-כל אבקש את ששששאף סליוחך על שהשהיתי את תשובתי זמן רב כל-כך. לא הייתי בקו הבריאות ואחר-כך, משהבראתי ביקשתי להתייעץ עם חברים על עיצוב דמותו של הקובץ לזכר גליה ירדני - והדבר ניתן לי רק בימים האחרונים ממש.
#
# קראתי את הפרק ששלמתאלי, ומובן מאליו שהייתי רוצה להביא בקובץ חלק מן העבודה החשובה הזאת. רצוי איפוא שכולה תהיה בידי, על-מנת שאבחור מתוכה אותם הפרקים, הקרובים ביותר והמתאימים ביותר לקובץ. כל כתב-היד יועתק במכונת-כתיבה ובבוא הזמן אחזיר לך העתק מלא.
#
# אני חוזר ומתנצל על השהיית תשובתי ומבקש ממך להמציא לי עתה בהקדם את כל כתב-היד.
#
# בברכה, הנזי דיי מ,
#
# Image
#
# Page 8:
# ===
#
#
# THEArEN ASSETT Lars|m ENTs can miyan gerta DE ngigry nokin cesit SU REACTION TE -(GENIT 02055 - MIT 0008 DONDE
#
# 1
#
# 玉
#
# Page 9:
# ===
#
#
# Image With Text:
# 2
# דואר אויר
# PAR AVION
#
# A.R.Malachi
#
# 2070 Grand Concourse Bronx N.Y. 10457 U.S.A.
#
# 55
#
# Page 10:
# ===
#
#
# הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב
# {'documentId': '7a1af467',
#  'dataset': 'unassigned',
#  'classified': False,
#  'classIds': None,
#  'filename': 'Archives_OCR',
#  'fileType': 'pdf',
#  'fileExtension': 'pdf',
#  'result': {'pages': [{'sections': [{'type': 'text',
#       'text': '30 39',
#       'bbox': [0.02861956238342592,
#        0.023884175580966432,
#        0.17393353522793364,
#        0.0644383281786454],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': "JaD' wild west faly",
#       'bbox': [0.2727883516174966,
#        0.3920920466475612,
#        0.6760193337478189,
#        0.44873450046817803],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '13WENT Taip Te 9900 1/3/2,N /N /3 PoJN-N.3N 2 15 + 1969',
#       'bbox': [0.03688253344297146,
#        0.4790029225661833,
#        0.8114458193778705,
#        0.574262974207644],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '5/25/6/12 /NO/3 Pp To pera pd >(?)',
#       'bbox': [0.14639698361444814,
#        0.6060068666118094,
#        0.804997894145725,
#        0.6602587747921573],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'שם תיק: ארכיון אליעזר רפאל מלאכי -קובץ לזכר גליה ירדני',
#       'bbox': [0.34475842843103827,
#        0.7871066594784779,
#        0.6967670122941777,
#        0.8147575405044972],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'מזהה פיזי:',
#       'bbox': [0.6253284129881069,
#        0.811522855602531,
#        0.6969675698441667,
#        0.823475583803876],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'פ-2446/30 001nder',
#       'bbox': [0.4733358737289665,
#        0.8134806912010896,
#        0.6039489781592828,
#        0.8517790766960814],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'מזהה פריט:',
#       'bbox': [0.6203946972583783,
#        0.8364285106262236,
#        0.6976494655141292,
#        0.8486578895099736],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'כתובת',
#       'bbox': [0.6498666292292573,
#        0.8529424282836308,
#        0.6965163153566916,
#        0.863667962432256],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '2-109-1-13-3',
#       'bbox': [0.5383265478028919,
#        0.8539284396901512,
#        0.6281161629329536,
#        0.86670402633147],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'תאריד הדפסה 06/05/2021',
#       'bbox': [0.34158961914121255,
#        0.8583690378231138,
#        0.5058261968271796,
#        0.8720738870130238],
#       'header': 'paragraph',
#       'tableList': None}],
#     'text': "30 39\n\nJaD' wild west faly\n\n13WENT Taip Te 9900 1/3/2,N /N /3 PoJN-N.3N 2 15 + 1969\n\n5/25/6/12 /NO/3 Pp To pera pd >(?)\n\nשם תיק: ארכיון אליעזר רפאל מלאכי -קובץ לזכר גליה ירדני\n\nמזהה פיזי:\n\nפ-2446/30 001nder\n\nמזהה פריט:\n\nכתובת\n\n2-109-1-13-3\n\nתאריד הדפסה 06/05/2021",
#     'pageNum': 0},
#    {'sections': [], 'text': '', 'pageNum': 1},
#    {'sections': [{'type': 'text',
#       'text': 'ההסתדרות הכללית של העובדים בארץ ישראל',
#       'bbox': [0.5025002819866903,
#        0.044916250028799856,
#        0.9408015941647555,
#        0.06061792963620026],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ',
#       'bbox': [0.5781667105312629,
#        0.07231066976937078,
#        0.8648719780426364,
#        0.11374789761076423],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'רח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 1,6040 תל־אביב',
#       'bbox': [0.5040794074519683,
#        0.12616639402806257,
#        0.9441102379967665,
#        0.1569707163099325],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'יום.',
#       'bbox': [0.36178892356280784,
#        0.15221298066953895,
#        0.39600330864383204,
#        0.1656221920143769],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '7 במאי 1969',
#       'bbox': [0.1551678760762492,
#        0.14163767481510495,
#        0.3181937812535249,
#        0.16062253761260742],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'לא״ר מלאכי שלום רב,',
#       'bbox': [0.5770199646576681,
#        0.23843973918853534,
#        0.8600030078580291,
#        0.2571250835195724],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'כמי שהוטל עליו להתקין קובץ לזכרה של גליה ירדני הנני פונה אליך בזה בבקשה להמציא לנו את תרומתך לקובץ הזה, שיכיל שלושה מדורים: א) דברים על גליה ועל עבודתה המדעית; ב) חיבורים, מקשש הקשורים במישרין עם נושא מחקרה על הישוב בא״י בכלל ועל ירושלים בפרט; ב) מאמרים שלה, בעניינים שונים, שראו אור בזמנם.',
#       'bbox': [0.0039854118885588605,
#        0.26250489597493265,
#        0.8490807233898561,
#        0.44619035550537983],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'מדבריו של שמואל אגמון למדתי כי מוכנות אצלך הן רשימה על אישיותה של גליה והן עבודה מדעית מקיפה, הראויות לבוא שתיהן בקובץ הזה. אודה לך איפוא אם תואיל לשלוח לי את כתביהיד בהקדם.',
#       'bbox': [0.0005639733804564424,
#        0.45116697002511347,
#        0.845283302628116,
#        0.5697071630993249],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'image',
#       'text': 'Image With Text:\nבברכה,\nאנPA גר מן',
#       'bbox': [0.19703350001879913,
#        0.6065940142386471,
#        0.3894424183178554,
#        0.7649125636476741],
#       'header': None,
#       'tableList': None},
#      {'type': 'image',
#       'text': 'Image',
#       'bbox': [0.8500394781366319,
#        0.8773587079234154,
#        0.9426063089822161,
#        0.9771674769025183],
#       'header': None,
#       'tableList': None}],
#     'text': 'ההסתדרות הכללית של העובדים בארץ ישראל\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ\n\nרח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 1,6040 תל־אביב\n\nיום.\n\n7 במאי 1969\n\nלא״ר מלאכי שלום רב,\n\nכמי שהוטל עליו להתקין קובץ לזכרה של גליה ירדני הנני פונה אליך בזה בבקשה להמציא לנו את תרומתך לקובץ הזה, שיכיל שלושה מדורים: א) דברים על גליה ועל עבודתה המדעית; ב) חיבורים, מקשש הקשורים במישרין עם נושא מחקרה על הישוב בא״י בכלל ועל ירושלים בפרט; ב) מאמרים שלה, בעניינים שונים, שראו אור בזמנם.\n\nמדבריו של שמואל אגמון למדתי כי מוכנות אצלך הן רשימה על אישיותה של גליה והן עבודה מדעית מקיפה, הראויות לבוא שתיהן בקובץ הזה. אודה לך איפוא אם תואיל לשלוח לי את כתביהיד בהקדם.\n\nImage With Text:\nבברכה,\nאנPA גר מן\n\nImage',
#     'pageNum': 2},
#    {'sections': [], 'text': '', 'pageNum': 3},
#    {'sections': [{'type': 'image',
#       'text': 'Image With Text:\nדואר אויר PAR AVION',
#       'bbox': [0.030246595387352637,
#        0.11764824852358223,
#        0.2946008413841268,
#        0.42870722433460073],
#       'header': None,
#       'tableList': None},
#      {'type': 'text',
#       'text': 'A.R. Malachi 2070 Grand Concourse Bronx N.Y. 10457',
#       'bbox': [0.3214719233775088,
#        0.22409190194968048,
#        0.6788273832288532,
#        0.3893900169889168],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'U.S.A',
#       'bbox': [0.3558422986747369,
#        0.45645578836663697,
#        0.4448860140674105,
#        0.4882695574791684],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'Now',
#       'bbox': [0.796005919619548,
#        0.23729876223606505,
#        0.9106569780009646,
#        0.5512701237763935],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'image',
#       'text': 'Image With Text:\nF\n-7.5.59\nTEL\nAFO\n0.80',
#       'bbox': [0.05791582833103311,
#        0.5512094490736995,
#        0.9215151565539833,
#        0.8206860286384597],
#       'header': None,
#       'tableList': None}],
#     'text': 'Image With Text:\nדואר אויר PAR AVION\n\nA.R. Malachi 2070 Grand Concourse Bronx N.Y. 10457\n\nU.S.A\n\nNow\n\nImage With Text:\nF\n-7.5.59\nTEL\nAFO\n0.80',
#     'pageNum': 4},
#    {'sections': [{'type': 'text',
#       'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב',
#       'bbox': [0.30086666666666667,
#        0.08463473005313756,
#        0.71555,
#        0.19847483064941387],
#       'header': 'paragraph',
#       'tableList': None}],
#     'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב',
#     'pageNum': 5},
#    {'sections': [{'type': 'text',
#       'text': 'ההסתדרות הכללית של העובדים בארץ ישראל',
#       'bbox': [0.5094428528347407,
#        0.052309900566044294,
#        0.9497700542822678,
#        0.066987695192675],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ',
#       'bbox': [0.5708873642943305,
#        0.07877160286610564,
#        0.8873642943305187,
#        0.11756126358679926],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'רח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 16040 תל־אביב',
#       'bbox': [0.5120438781664656,
#        0.12662491752422186,
#        0.9493553980699638,
#        0.16164094965794257],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '15 ביוני 1969',
#       'bbox': [0.24057599517490952,
#        0.18297468427693342,
#        0.43712303980699635,
#        0.2026183889152554],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'לא״ר מלאכי שלום וברכה,',
#       'bbox': [0.5521712907117009,
#        0.2446839296669715,
#        0.8805601628468034,
#        0.26425818101841675],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'קודם-כל אבקש את ששששאף סליוחך על שהשהיתי את תשובתי זמן רב כל-כך. לא הייתי בקו הבריאות ואחר-כך, משהבראתי ביקשתי להתייעץ עם חברים על עיצוב דמותו של הקובץ לזכר גליה ירדני - והדבר ניתן לי רק בימים האחרונים ממש.',
#       'bbox': [0.018753769601930037,
#        0.27627359964810333,
#        0.9274728588661036,
#        0.39045480327356497],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'קראתי את הפרק ששלמתאלי, ומובן מאליו שהייתי רוצה להביא בקובץ חלק מן העבודה החשובה הזאת. רצוי איפוא שכולה תהיה בידי, על-מנת שאבחור מתוכה אותם הפרקים, הקרובים ביותר והמתאימים ביותר לקובץ. כל כתב-היד יועתק במכונת-כתיבה ובבוא הזמן אחזיר לך העתק מלא.',
#       'bbox': [0.005484770808202654,
#        0.40231973978168517,
#        0.9277932750301568,
#        0.5437729340541042],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'אני חוזר ומתנצל על השהיית תשובתי ומבקש ממך להמציא לי עתה בהקדם את כל כתב-היד.',
#       'bbox': [0.04825090470446321,
#        0.556008288092234,
#        0.9283210193003618,
#        0.6070680294944958],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': 'בברכה, הנזי דיי מ,',
#       'bbox': [0.1656363088057901,
#        0.6276725046012802,
#        0.4525972557297949,
#        0.7640324578360671],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'image',
#       'text': 'Image',
#       'bbox': [0.860524728588661,
#        0.8685828056812789,
#        0.9495438781664656,
#        0.9687807475488777],
#       'header': None,
#       'tableList': None}],
#     'text': 'ההסתדרות הכללית של העובדים בארץ ישראל\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ\n\nרח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 16040 תל־אביב\n\n15 ביוני 1969\n\nלא״ר מלאכי שלום וברכה,\n\nקודם-כל אבקש את ששששאף סליוחך על שהשהיתי את תשובתי זמן רב כל-כך. לא הייתי בקו הבריאות ואחר-כך, משהבראתי ביקשתי להתייעץ עם חברים על עיצוב דמותו של הקובץ לזכר גליה ירדני - והדבר ניתן לי רק בימים האחרונים ממש.\n\nקראתי את הפרק ששלמתאלי, ומובן מאליו שהייתי רוצה להביא בקובץ חלק מן העבודה החשובה הזאת. רצוי איפוא שכולה תהיה בידי, על-מנת שאבחור מתוכה אותם הפרקים, הקרובים ביותר והמתאימים ביותר לקובץ. כל כתב-היד יועתק במכונת-כתיבה ובבוא הזמן אחזיר לך העתק מלא.\n\nאני חוזר ומתנצל על השהיית תשובתי ומבקש ממך להמציא לי עתה בהקדם את כל כתב-היד.\n\nבברכה, הנזי דיי מ,\n\nImage',
#     'pageNum': 6},
#    {'sections': [{'type': 'text',
#       'text': 'THEArEN ASSETT Lars|m ENTs can miyan gerta DE ngigry nokin cesit SU REACTION TE -(GENIT 02055 - MIT 0008 DONDE',
#       'bbox': [0.047621747264584166,
#        0.05181903146526359,
#        0.4888788102122192,
#        0.16023399910000347],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '1',
#       'bbox': [0.1424305988623694,
#        0.5217787623893754,
#        0.19437987792202885,
#        0.537944084830443],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '玉',
#       'bbox': [0.8756354290681635,
#        0.82518144160984,
#        0.9123911030481698,
#        0.8422006069207426],
#       'header': 'paragraph',
#       'tableList': None}],
#     'text': 'THEArEN ASSETT Lars|m ENTs can miyan gerta DE ngigry nokin cesit SU REACTION TE -(GENIT 02055 - MIT 0008 DONDE\n\n1\n\n玉',
#     'pageNum': 7},
#    {'sections': [{'type': 'image',
#       'text': 'Image With Text:\n2\nדואר אויר\nPAR AVION',
#       'bbox': [0.08727520391781667,
#        0.09390878607722532,
#        0.31772260690482756,
#        0.4448581596757935],
#       'header': None,
#       'tableList': None},
#      {'type': 'text',
#       'text': 'A.R.Malachi',
#       'bbox': [0.3795871373668251,
#        0.30480755384583735,
#        0.5678726060940211,
#        0.3389150603772808],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '2070 Grand Concourse Bronx N.Y. 10457 U.S.A.',
#       'bbox': [0.3811276695801644,
#        0.38884203163892944,
#        0.7197528662007233,
#        0.5555738413116372],
#       'header': 'paragraph',
#       'tableList': None},
#      {'type': 'text',
#       'text': '55',
#       'bbox': [0.3378954708352928,
#        0.6936290140091748,
#        0.3778033632250637,
#        0.7932360988253686],
#       'header': 'paragraph',
#       'tableList': None}],
#     'text': 'Image With Text:\n2\nדואר אויר\nPAR AVION\n\nA.R.Malachi\n\n2070 Grand Concourse Bronx N.Y. 10457 U.S.A.\n\n55',
#     'pageNum': 8},
#    {'sections': [{'type': 'text',
#       'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב',
#       'bbox': [0.30488558054869325,
#        0.08145707486728905,
#        0.7179332986607724,
#        0.19230378099131534],
#       'header': 'paragraph',
#       'tableList': None}],
#     'text': 'הוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב',
#     'pageNum': 9}],
#   'numPages': 10,
#   'text': "Page 1:\n===\n\n30 39\n\nJaD' wild west faly\n\n13WENT Taip Te 9900 1/3/2,N /N /3 PoJN-N.3N 2 15 + 1969\n\n5/25/6/12 /NO/3 Pp To pera pd >(?)\n\nשם תיק: ארכיון אליעזר רפאל מלאכי -קובץ לזכר גליה ירדני\n\nמזהה פיזי:\n\nפ-2446/30 001nder\n\nמזהה פריט:\n\nכתובת\n\n2-109-1-13-3\n\nתאריד הדפסה 06/05/2021\n\n\nPage 2:\n===\n\n\n\n\nPage 3:\n===\n\nההסתדרות הכללית של העובדים בארץ ישראל\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ\n\nרח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 1,6040 תל־אביב\n\nיום.\n\n7 במאי 1969\n\nלא״ר מלאכי שלום רב,\n\nכמי שהוטל עליו להתקין קובץ לזכרה של גליה ירדני הנני פונה אליך בזה בבקשה להמציא לנו את תרומתך לקובץ הזה, שיכיל שלושה מדורים: א) דברים על גליה ועל עבודתה המדעית; ב) חיבורים, מקשש הקשורים במישרין עם נושא מחקרה על הישוב בא״י בכלל ועל ירושלים בפרט; ב) מאמרים שלה, בעניינים שונים, שראו אור בזמנם.\n\nמדבריו של שמואל אגמון למדתי כי מוכנות אצלך הן רשימה על אישיותה של גליה והן עבודה מדעית מקיפה, הראויות לבוא שתיהן בקובץ הזה. אודה לך איפוא אם תואיל לשלוח לי את כתביהיד בהקדם.\n\nImage With Text:\nבברכה,\nאנPA גר מן\n\nImage\n\n\nPage 4:\n===\n\n\n\n\nPage 5:\n===\n\nImage With Text:\nדואר אויר PAR AVION\n\nA.R. Malachi 2070 Grand Concourse Bronx N.Y. 10457\n\nU.S.A\n\nNow\n\nImage With Text:\nF\n-7.5.59\nTEL\nAFO\n0.80\n\n\nPage 6:\n===\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב\n\n\nPage 7:\n===\n\nההסתדרות הכללית של העובדים בארץ ישראל\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ\n\nרח׳ פומבדיתא 17 - טלפון 220402 - ת. ד. 16040 תל־אביב\n\n15 ביוני 1969\n\nלא״ר מלאכי שלום וברכה,\n\nקודם-כל אבקש את ששששאף סליוחך על שהשהיתי את תשובתי זמן רב כל-כך. לא הייתי בקו הבריאות ואחר-כך, משהבראתי ביקשתי להתייעץ עם חברים על עיצוב דמותו של הקובץ לזכר גליה ירדני - והדבר ניתן לי רק בימים האחרונים ממש.\n\nקראתי את הפרק ששלמתאלי, ומובן מאליו שהייתי רוצה להביא בקובץ חלק מן העבודה החשובה הזאת. רצוי איפוא שכולה תהיה בידי, על-מנת שאבחור מתוכה אותם הפרקים, הקרובים ביותר והמתאימים ביותר לקובץ. כל כתב-היד יועתק במכונת-כתיבה ובבוא הזמן אחזיר לך העתק מלא.\n\nאני חוזר ומתנצל על השהיית תשובתי ומבקש ממך להמציא לי עתה בהקדם את כל כתב-היד.\n\nבברכה, הנזי דיי מ,\n\nImage\n\n\nPage 8:\n===\n\nTHEArEN ASSETT Lars|m ENTs can miyan gerta DE ngigry nokin cesit SU REACTION TE -(GENIT 02055 - MIT 0008 DONDE\n\n1\n\n玉\n\n\nPage 9:\n===\n\nImage With Text:\n2\nדואר אויר\nPAR AVION\n\nA.R.Malachi\n\n2070 Grand Concourse Bronx N.Y. 10457 U.S.A.\n\n55\n\n\nPage 10:\n===\n\nהוצאת ספרים של הקיבוץ המאוחד בע״מ טלפון: 220402 ת. ד. 16040 תל־אביב",
#   'language': 'he'},
#  'numPages': 10,
#  'language': 'he',
#  'metadata': None,
#  'status': 'completed',
#  'timestamp': '2025-05-18T11:13:40.051000Z'}
